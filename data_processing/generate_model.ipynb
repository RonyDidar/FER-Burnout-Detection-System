# %%
### ========================================================================================================================================
## Name:        Saputra Rizky Johan (사푸트라)
## Institution: Seoul National University, South Korea
## Purpose:     Undergraduate Thesis
## Department:  Computer Science and Engineering
## College:     Engineering
## Advisor:     Prof. Lee Changun (이창건 교수)
## Title:       The Application of Facial Emotion Recognition (FER) in the Detection and Measurement of Burnout and Prolonged Stress Levels
## Module:      generate_model.ipynb (A notebook file to download the Emo0.1.h5 dataset into a local machine)
### ========================================================================================================================================

# =============================================================================================
# SETUP
# =============================================================================================
# Install Huggingface (Recommended: Run via Google Colab)
# !pip install -q huggingface_hub

# Download the model file from Hugging Face
from huggingface_hub import hf_hub_download
import shutil

# =============================================================================================
# IMPLEMENTATION
# =============================================================================================
# Download to cache
cached_path = hf_hub_download(
    repo_id="shivamprasad1001/Emo0.1",
    filename="Emo0.1.h5"
)

# Copy from cache to a working local directory
local_path = "/content/Emo0.1.h5"
shutil.copy(cached_path, local_path)

print("Model saved to:", local_path)

# Load the downloadable link for local machine
from google.colab import files
files.download(local_path)

### ===================================================================================================================================
## END: Add implementations if necessary
### ===================================================================================================================================
# Out:
# Model saved to: /content/Emo0.1.h5
